# %% [markdown]
# https://dynamics-and-control.readthedocs.io/en/latest/0_Getting_Started/Notebook%20introduction.html

# %%
from sympy import *
init_printing()
x = Symbol('x')

# %%
a = 4*exp(x)
print(a.)
plot(a)
# Out:
# 4*exp(x)
