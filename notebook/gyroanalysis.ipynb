# %% [markdown]
# Gyro Analysis
# 360 Degrees
# 10m Radius

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

# %% [markdown]
# Plot of the Z axis Gyro

# %%
headers = ['x', 'y', 'z', 'dT']
df = pd.read_csv('robobuoy_gyro_360_radius10m.csv', names=headers )
df['z'].plot()
plt.show()

# %% [markdown]
# Plot of dT
# shost a pretty constant 20ms cycle time, bit around hte 600 samples looks
# inconsistant. this coud be because I am 20m away and the ble singal does not cope ?

# %%
df['dT'].plot()
plt.show()
print('mean cycle time' , df['dT'].mean())
# Out:
# mean cycle time 0.019473649137931034
